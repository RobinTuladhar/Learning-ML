# %% [markdown]
# # Before diving forward do check these funcitons in order to get better understading of the data so that the analysis can be easier and faster

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.sample(5) # Use sample to get different datas avoid using head or tail as it may provide similar datas
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 776          777         0       3                Tobin, Mr. Roger    male
# 403          404         0       3  Hakkarainen, Mr. Pekka Pietari    male
# 499          500         0       3              Svensson, Mr. Olof    male
# 178          179         0       2              Hale, Mr. Reginald    male
# 318          319         1       1        Wick, Miss. Mary Natalie  female
#
#       Age  SibSp  Parch            Ticket      Fare Cabin Embarked
# 776   NaN      0      0            383121    7.7500   F38        Q
# 403  28.0      1      0  STON/O2. 3101279   15.8500   NaN        S
# 499  24.0      0      0            350035    7.7958   NaN        S
# 178  30.0      0      0            250653   13.0000   NaN        S
# 318  31.0      0      2             36928  164.8667    C7        S

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include ="all") # gives every possible mathematics
# Out:
#         PassengerId    Survived      Pclass             Name   Sex  \
# count    891.000000  891.000000  891.000000              891   891
# unique          NaN         NaN         NaN              891     2
# top             NaN         NaN         NaN  Flynn, Mr. John  male
# freq            NaN         NaN         NaN                1   577
# mean     446.000000    0.383838    2.308642              NaN   NaN
# std      257.353842    0.486592    0.836071              NaN   NaN
# min        1.000000    0.000000    1.000000              NaN   NaN
# 25%      223.500000    0.000000    2.000000              NaN   NaN
# 50%      446.000000    0.000000    3.000000              NaN   NaN
# 75%      668.500000    1.000000    3.000000              NaN   NaN
# max      891.000000    1.000000    3.000000              NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare Cabin Embarked
# count   714.000000  891.000000  891.000000    891  891.000000   204      889
# ...

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum() # no dupicates
# Out:
# 0

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df.corr() # gives the co-relation between all the cloumns
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# this line is giving the co-realtion of all the columns with respect to srurived class below the co-relation betwenn survied
# is very high with fare, meaning those with high fare pay had better chances of surviving.
# The corelation with passengerid is the minimum meaning the column is useless and it is better to drop as it doesnt provide
# any significance
df.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# # 8. Drop any column if necessary

# %%
df.drop("PassengerId", axis=1) # asix=1 means the value is present in columns if not given it will check in rows and return error
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...
