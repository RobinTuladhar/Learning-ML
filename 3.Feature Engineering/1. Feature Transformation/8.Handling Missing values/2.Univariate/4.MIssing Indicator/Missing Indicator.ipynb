# %% [markdown]
# # Missing Indicator
# Here ou make a new column for all the columns which contains null vlaues, and fill those newly generated columns with true and flase. True for the coresspoind null value and False for all the other present values. This metod sometimes helps to increase the accuracy of the model. It is believed that this technique helps the model to diffrientiate between the missing and non-missing rows.

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.impute import MissingIndicator,SimpleImputer

# %%
df = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#       Age     Fare
# 30   40.0  27.7208
# 10    4.0  16.7000
# 873  47.0   9.0000
# 182   9.0  31.3875
# 876  20.0   9.8458

# %%
y_test.head()
# Out:
# 707    1
# 37     0
# 615    1
# 169    0
# 68     1
# Name: Survived, dtype: int64

# %% [markdown]
# ## Calculating the accuracy of the model without using the missing indicator technique

# %%
si = SimpleImputer()
X_train_trf = si.fit_transform(X_train)
X_test_trf = si.transform(X_test)

# %%
X_train_trf
# Out:
# array([[ 40.        ,  27.7208    ],
#        [  4.        ,  16.7       ],
#        [ 47.        ,   9.        ],
#        ...,
#        [ 71.        ,  49.5042    ],
#        [ 29.78590426, 221.7792    ],
#        [ 29.78590426,  25.925     ]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

clf = LogisticRegression()
clf.fit(X_train_trf,y_train)
y_pred = clf.predict(X_test_trf)
accuracy_score(y_test,y_pred)*100
# Out:
# 61.452513966480446

# %% [markdown]
# # AFter Using the missing indicator

# %%
mi = MissingIndicator()

mi.fit(X_train)
# Out:
# MissingIndicator()

# %%
mi.features_ #shows where the missing values are
# Out:
# array([0], dtype=int64)

# %%
X_train_missing = mi.transform(X_train)

# %%
X_train_missing
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
X_test_missing = mi.transform(X_test)

# %%
X_test_missing
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
X_train['Age_NA'] = X_train_missing

# %%
X_test['Age_NA'] = X_test_missing

# %%
X_train
# Out:
#       Age      Fare  Age_NA
# 30   40.0   27.7208   False
# 10    4.0   16.7000   False
# 873  47.0    9.0000   False
# 182   9.0   31.3875   False
# 876  20.0    9.8458   False
# ..    ...       ...     ...
# 534  30.0    8.6625   False
# 584   NaN    8.7125    True
# 493  71.0   49.5042   False
# 527   NaN  221.7792    True
# 168   NaN   25.9250    True
#
# [712 rows x 3 columns]

# %%
si = SimpleImputer()

X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173

# %% [markdown]
# ## Now form sklearn the above hazzle can all be done in a sible line by just making he indicator True

# %%
si = SimpleImputer(add_indicator=True) # THis line of code does the ssame exact thing as above and prevents doing all the extra things

# %%
X_train = si.fit_transform(X_train)

# %%
X_test = si.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173
